# %% [markdown]
# 1.Загрузить файл hr.csv.
#
# 2.Рассчитать основные статистики для переменных (среднее,медиана,мода,мин/макс,сред.отклонение).
#
# 3.Рассчитать и визуализировать корреляционную матрицу для переменных.
#
# 4.Визуализировать несколько взаимосвязей между переменными.
#
# 5.С использованием t-test статистики проверить взаимосвязи между несколькими переменными.
#
# 6.Рассчитать сколько работников работает в каждом департаменте.
#
# 7.Показать распределение сотрудников по зарплатам.
#
# 8.Показать распределение сотрудников по зарплатам совместно с департаментами.
#
# 9.Сколько сотрудников покинули компанию.
#
# 10.Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию.
#
# 11.Загрузить результат (в формате .ipynb ноутбука) в репозиторий. Разместить ссылку на репозиторий в Личном кабинете

# %%
import statistics
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
sns.set_style('darkgrid')
from scipy.stats import pearsonr
import ssl
import researchpy as rp

# %%
from IPython.display import Image
Image(filename="download.png", width=400, height=400)

# %% [markdown]
# 1.Загрузить файл hr.csv.

# %%
data = pd.read_csv('hr.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# В Датасете 14999 записей:

# %%
len(data)
# Out:
# 14999

# %% [markdown]
# 2.Рассчитать основные статистики для переменных (среднее,медиана,мода,мин/макс,сред.отклонение).

# %%
for i in data.iloc[:,:8].columns:
    print('Среднее значение переменной', i,': ', statistics.mean(data[i]))
    print('Медиана переменной ', i,': ', statistics.median(data[i]))
    try:
        print('Мода переменной ', i,': ', statistics.mode(data[i]))
    except:
        print('!!! Невозможно вычислить моду переменной', i)
    print('Минимальное и максимальное значение переменной ', i,': ', min(data[i]), ' и ', max(data[i]))
    print('Среднее отклонение переменной ', i,': ', statistics.pstdev(data[i]))
    print('\t')
# Out:
# Среднее значение переменной satisfaction_level :  0.6128335222348157
# Медиана переменной  satisfaction_level :  0.64
# Мода переменной  satisfaction_level :  0.1
# Минимальное и максимальное значение переменной  satisfaction_level :  0.09  и  1.0
# Среднее отклонение переменной  satisfaction_level :  0.2486223626820733
#
# Среднее значение переменной last_evaluation :  0.7161017401160077
# Медиана переменной  last_evaluation :  0.72
# Мода переменной  last_evaluation :  0.55
# Минимальное и максимальное значение переменной  last_evaluation :  0.36  и  1.0
# Среднее отклонение переменной  last_evaluation :  0.1711634045107436
#
# Среднее значение переменной number_project :  3.80305353690246
# Медиана переменной  number_project :  4
# Мода переменной  number_project :  4
# Минимальное и максимальное значение переменной  number_project :  2  и  7
# Среднее отклонение переменной  number_project :  1.2325512654823438
#
# Среднее значение переменной average_montly_hours :  201.0503366891126
# Медиана переменной  average_montly_hours :  200
# !!! Невозможно вычислить моду переменной average_montly_hours
# Минимальное и максимальное значение переменной  average_montly_hours :  96  и  310
# Среднее отклонение переменной  average_montly_hours :  49.94143446256218
#
# Среднее значение переменной time_spend_company :  3.498233215547703
# Медиана переменной  time_spend_company :  3
# Мода переменной  time_spend_company :  3
# Минимальное и максимальное значение переменной  time_spend_company :  2  и  10
# Среднее отклонение переменной  time_spend_company :  1.4600875552715114
#
# Среднее значение переменной Work_accident :  0.1446096406427095
# Медиана переменной  Work_accident :  0
# Мода переменной  Work_accident :  0
# Минимальное и максимальное значение переменной  Work_accident :  0  и  1
# Среднее отклонение переменной  Work_accident :  0.3517068274513532
#
# Среднее значение переменной left :  0.2380825388359224
# Медиана переменной  left :  0
# Мода переменной  left :  0
# Минимальное и максимальное значение переменной  left :  0  и  1
# Среднее отклонение переменной  left :  0.42590990072709495
#
# Среднее значение переменной promotion_last_5years :  0.021268084538969265
# Медиана переменной  promotion_last_5years :  0
# Мода переменной  promotion_last_5years :  0
# Минимальное и максимальное значение переменной  promotion_last_5years :  0  и  1
# Среднее отклонение переменной  promotion_last_5years :  0.14427665479561314

# %% [markdown]
# 3.Рассчитать и визуализировать корреляционную матрицу для переменных.

# %%
f, ax = plt.subplots(figsize=(10, 10))
corr = np.round_(data.corr(), decimals=2)
sns.heatmap(corr, annot=True, cmap='RdYlGn', linewidths=0.2)

# %% [markdown]
# 4.Визуализировать несколько взаимосвязей между переменными.

# %%
data['salary_to_numb'] = [0 if x=='low' else  0.5 if x=='medium' else 1 for x in data['salary'] ]
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  salary_to_numb
# 0     low             0.0
# 1  medium             0.5
# 2  medium             0.5
# 3     low             0.0
# 4     low             0.0

# %%
plt.scatter(data.satisfaction_level, data.last_evaluation)
plt.show()

# %%
plt.scatter(data.satisfaction_level, data.average_montly_hours)
plt.show()

# %%
sns.pairplot(data=data[['satisfaction_level','last_evaluation',
                        'average_montly_hours', 'time_spend_company', 
                        'Work_accident', 'left','promotion_last_5years', 'salary']], 
                         hue='salary')
plt.show()

# %% [markdown]
# 5.С использованием t-test статистики проверить взаимосвязи между несколькими переменными.

# %%
for i in data.iloc[:,:7].columns:
    for j in data.iloc[:,:7].columns:
        if i==j:
            continue
        print('для переменных {} и {}'.format(i,j),'\n')
        print(stats.ttest_ind(data[i],data[j]))
        print("________________________")
# Out:
# для переменных satisfaction_level и last_evaluation
#
# Ttest_indResult(statistic=-41.89868154070206, pvalue=0.0)
# ________________________
# для переменных satisfaction_level и number_project
#
# Ttest_indResult(statistic=-310.721972689063, pvalue=0.0)
# ________________________
# для переменных satisfaction_level и average_montly_hours
#
# Ttest_indResult(statistic=-491.5064991295991, pvalue=0.0)
# ________________________
# для переменных satisfaction_level и time_spend_company
#
# Ttest_indResult(statistic=-238.58170166684755, pvalue=0.0)
# ________________________
# для переменных satisfaction_level и Work_accident
#
# Ttest_indResult(statistic=133.13298501842021, pvalue=0.0)
# ________________________
# для переменных satisfaction_level и left
#
# Ttest_indResult(statistic=93.06077566920372, pvalue=0.0)
# ________________________
# для переменных last_evaluation и satisfaction_level
#
# Ttest_indResult(statistic=41.89868154070206, pvalue=0.0)
# ________________________
# для переменных last_evaluation и number_project
#
# Ttest_indResult(statistic=-303.8042100031241, pvalue=0.0)
# ________________________
# для переменных last_evaluation и average_montly_hours
#
# Ttest_indResult(statistic=-491.25647025928, pvalue=0.0)
# ________________________
# для переменных last_evaluation и time_spend_company
#
# Ttest_indResult(statistic=-231.7670054076573, pvalue=0.0)
# ________________________
# для переменных last_evaluation и Work_accident
#
# Ttest_indResult(statistic=178.9323432205496, pvalue=0.0)
# ________________________
# для переменных last_evaluation и left
#
# Ttest_indResult(statistic=127.53627018536089, pvalue=0.0)
# ________________________
# для переменных number_project и satisfaction_level
#
# Ttest_indResult(statistic=310.721972689063, pvalue=0.0)
# ________________________
# для переменных number_project и last_evaluation
#
# Ttest_indResult(statistic=303.8042100031241, pvalue=0.0)
# ________________________
# для переменных number_project и average_montly_hours
#
# Ttest_indResult(statistic=-483.54229603425085, pvalue=0.0)
# ________________________
# для переменных number_project и time_spend_company
#
# Ttest_indResult(statistic=19.536753519083355, pvalue=1.7938911515379e-84)
# ________________________
# для переменных number_project и Work_accident
#
# Ttest_indResult(statistic=349.5506476012312, pvalue=0.0)
# ________________________
# для переменных number_project и left
#
# Ttest_indResult(statistic=334.7910997210306, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и satisfaction_level
#
# Ttest_indResult(statistic=491.5064991295991, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и last_evaluation
#
# Ttest_indResult(statistic=491.25647025928, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и number_project
#
# Ttest_indResult(statistic=483.54229603425085, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и time_spend_company
#
# Ttest_indResult(statistic=484.23011415607965, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и Work_accident
#
# Ttest_indResult(statistic=492.6485513145602, pvalue=0.0)
# ________________________
# для переменных average_montly_hours и left
#
# Ttest_indResult(statistic=492.4136472501141, pvalue=0.0)
# ________________________
# для переменных time_spend_company и satisfaction_level
#
# Ttest_indResult(statistic=238.58170166684755, pvalue=0.0)
# ________________________
# для переменных time_spend_company и last_evaluation
#
# Ttest_indResult(statistic=231.7670054076573, pvalue=0.0)
# ________________________
# для переменных time_spend_company и number_project
#
# Ttest_indResult(statistic=-19.536753519083355, pvalue=1.7938911515379e-84)
# ________________________
# для переменных time_spend_company и average_montly_hours
#
# Ttest_indResult(statistic=-484.23011415607965, pvalue=0.0)
# ________________________
# для переменных time_spend_company и Work_accident
#
# Ttest_indResult(statistic=273.46669095458304, pvalue=0.0)
# ________________________
# для переменных time_spend_company и left
#
# Ttest_indResult(statistic=262.50803476202543, pvalue=0.0)
# ________________________
# для переменных Work_accident и satisfaction_level
#
# Ttest_indResult(statistic=-133.13298501842021, pvalue=0.0)
# ________________________
# для переменных Work_accident и last_evaluation
#
# Ttest_indResult(statistic=-178.9323432205496, pvalue=0.0)
# ________________________
# для переменных Work_accident и number_project
#
# Ttest_indResult(statistic=-349.5506476012312, pvalue=0.0)
# ________________________
# для переменных Work_accident и average_montly_hours
#
# Ttest_indResult(statistic=-492.6485513145602, pvalue=0.0)
# ________________________
# для переменных Work_accident и time_spend_company
#
# Ttest_indResult(statistic=-273.46669095458304, pvalue=0.0)
# ________________________
# для переменных Work_accident и left
#
# Ttest_indResult(statistic=-20.724471296371643, pvalue=9.625063899986344e-95)
# ________________________
# для переменных left и satisfaction_level
#
# Ttest_indResult(statistic=-93.06077566920372, pvalue=0.0)
# ________________________
# для переменных left и last_evaluation
#
# Ttest_indResult(statistic=-127.53627018536089, pvalue=0.0)
# ________________________
# для переменных left и number_project
#
# Ttest_indResult(statistic=-334.7910997210306, pvalue=0.0)
# ________________________
# для переменных left и average_montly_hours
#
# Ttest_indResult(statistic=-492.4136472501141, pvalue=0.0)
# ________________________
# для переменных left и time_spend_company
#
# Ttest_indResult(statistic=-262.50803476202543, pvalue=0.0)
# ________________________
# для переменных left и Work_accident
#
# Ttest_indResult(statistic=20.724471296371643, pvalue=9.625063899986344e-95)
# ________________________

# %% [markdown]
# p-value равен 0 или имеет близкое ему значение во всех тестах, то есть меньше альфа значения 0.05:
# Можно сделать вывод что все переменные имеют статистическое различие.

# %% [markdown]
# 6.Рассчитать сколько работников работает в каждом департаменте.

# %%
data_working = data[ data['left']!=1 ]  # сотрдуники работающие в комапнии на данный момент

# %%
print('Кол-во работников по департаментам:')
data_working.sales.value_counts()  # работников в каждом департаменте
# Out:
# Кол-во работников по департаментам:
# sales          3126
# technical      2023
# support        1674
# IT              954
# product_mng     704
# RandD           666
# marketing       655
# accounting      563
# management      539
# hr              524
# Name: sales, dtype: int64

# %% [markdown]
# 7.Показать распределение сотрудников по зарплатам.

# %%
workers_barh = data_working.salary.value_counts().to_frame()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10,7
workers_barh.plot(kind='bar')
plt.title('Распределение сотрудников по зарплатам')
plt.xlabel('Уровень зарплат')
plt.ylabel('Кол-во работающих сотрудников')
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# 8.Показать распределение сотрудников по зарплатам совместно с департаментами.

# %%
new = data_working.groupby([data_working.salary, data_working.sales]).count().iloc[:,:1]
new.columns = ['cnt']

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,7
new.unstack('sales').plot(kind='bar')
plt.title('Распределение сотрудников по зарплатам совместно с департаментами')
plt.xlabel('Уровень зарплат')
plt.ylabel('Кол-во работающих сотрудников')
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# 9.Сколько сотрудников покинули компанию.

# %%
print('За все время {} сотрудник покинул комапнию'.format(data[data['left']==1].left.count()))
# Out:
# За все время 3571 сотрудник покинул комапнию

# %% [markdown]
# 10.Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию.

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  salary_to_numb
# 0     low             0.0
# 1  medium             0.5
# 2  medium             0.5
# 3     low             0.0
# 4     low             0.0

# %% [markdown]
#  Создаем две выборки люди, которые больше не работают в компании и работники организации

# %%
employees_left = data[ data['left']==1 ] # уволен
employees = data[ data['left']!=1 ] # работает

# %% [markdown]
# ___________

# %% [markdown]
# Протестируем гипотезу что люди уволенные имеют меньший уровень удовлетворенности

# %%
descriptives, results = rp.ttest(employees_left.satisfaction_level, employees.satisfaction_level)
print(descriptives)
print('_______________________________________')
print(results)
# Out:
#              Variable        N      Mean        SD        SE  95% Conf.  \
# 0  satisfaction_level   3571.0  0.440098  0.263933  0.004417   0.431438
# 1  satisfaction_level  11428.0  0.666810  0.217104  0.002031   0.662829
# 2            combined  14999.0  0.612834  0.248631  0.002030   0.608854
#
#    Interval
# 0  0.448758
# 1  0.670790
# 2  0.616813
# _______________________________________
#                                   Independent t-test     results
# 0  Difference (satisfaction_level - satisfaction_...     -0.2267
# 1                              Degrees of freedom =   14997.0000
# 2                                               t =     -51.6128
# 3                           Two side test p value =       0.0000
# 4                          Difference < 0 p value =       0.0000
# 5                          Difference > 0 p value =       1.0000
# 6                                       Cohen's d =      -0.9895
# 7                                       Hedge's g =      -0.9894
# 8                                   Glass's delta =      -0.8590
# 9                                               r =       0.3884

# %% [markdown]
# По тесту можно сделать вывод, что средний уровень удовлетвореннсти у людей уволенных(0.44) ниже чем у людей
# которые работают в комапнии (0.67)
# Также можно заметить что есть разница между выборками p-value < 0.05

# %% [markdown]
# _____________

# %% [markdown]
# Протестируем гипотезу что уволенные работники получили меньшую оценку на тесте чем те, которые работают в компании

# %%
descriptives, results = rp.ttest(employees_left.last_evaluation, employees.last_evaluation)
print(descriptives)
print('_______________________________________')
print(results)
# Out:
#           Variable        N      Mean        SD        SE  95% Conf.  Interval
# 0  last_evaluation   3571.0  0.718113  0.197673  0.003308   0.711627  0.724598
# 1  last_evaluation  11428.0  0.715473  0.162005  0.001515   0.712503  0.718444
# 2         combined  14999.0  0.716102  0.171169  0.001398   0.713362  0.718841
# _______________________________________
#                                   Independent t-test     results
# 0  Difference (last_evaluation - last_evaluation) =       0.0026
# 1                              Degrees of freedom =   14997.0000
# 2                                               t =       0.8042
# 3                           Two side test p value =       0.4213
# 4                          Difference < 0 p value =       0.7894
# 5                          Difference > 0 p value =       0.2106
# 6                                       Cohen's d =       0.0154
# 7                                       Hedge's g =       0.0154
# 8                                   Glass's delta =       0.0134
# 9                                               r =       0.0066

# %% [markdown]
# Гипотеза не прошла проверку.
# Средняя оценка уволенных работников чуть выше (0.718 против 0.715),
# А также p-value > 0.05, можно сделать вывод что эти две выборки имеют статистическое сходство

# %% [markdown]
# __________________________

# %% [markdown]
# Протестируем гипотезу о том, что работники покинувшие комапнию получали меньше повышений за последние 5 лет.

# %%
descriptives, results = rp.ttest(employees_left.promotion_last_5years, employees.promotion_last_5years)
print(descriptives)
print('_______________________________________')
print(results)
# Out:
#                 Variable        N      Mean        SD        SE  95% Conf.  \
# 0  promotion_last_5years   3571.0  0.005321  0.072759  0.001218   0.002933
# 1  promotion_last_5years  11428.0  0.026251  0.159889  0.001496   0.023320
# 2               combined  14999.0  0.021268  0.144281  0.001178   0.018959
#
#    Interval
# 0  0.007708
# 1  0.029183
# 2  0.023577
# _______________________________________
#                                   Independent t-test     results
# 0  Difference (promotion_last_5years - promotion_...     -0.0209
# 1                              Degrees of freedom =   14997.0000
# 2                                               t =      -7.5812
# 3                           Two side test p value =       0.0000
# 4                          Difference < 0 p value =       0.0000
# 5                          Difference > 0 p value =       1.0000
# 6                                       Cohen's d =      -0.1453
# 7                                       Hedge's g =      -0.1453
# 8                                   Glass's delta =      -0.2877
# 9                                               r =       0.0618

# %% [markdown]
# Из теста можно сделать вывод что между выьорками имеется статистическое различие, p-value < 0.05.
# А также из расчета среднего значения видно, что сотрудники работающие в команпии чаще получали повышение за последние 5 лет.

# %% [markdown]
# _______

# %% [markdown]
# Узнаем на каком проекте люди чаще увольнялись.

# %%
left = data[data['left']==1].groupby(['number_project']).count().iloc[:,:1]

# %%
all_ = data.groupby(['number_project']).count().iloc[:,:1]

# %% [markdown]
# Построим график количества всех работников по каждому проекту

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10,7
all_.plot(kind='bar') # все сотрудники
plt.title('Кол-во сотрудников по проектам')
plt.xlabel('Номер проекта')
plt.ylabel('Кол-во сотрудников')
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# Построим график по количеству уволенных сотрудников по проектам

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10,7
left.plot(kind='bar')  # уволенные
plt.title('Кол-во уволенных сотрудников по проектам')
plt.xlabel('Номер проекта')
plt.ylabel('Кол-во уволенных сотрудников')
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# Из графика можно сделать вывод, что бОльшая часть уволенных людей принимала участие во втором проекте!
# А с проекта номер 3 уволилось меньше людей чем с других проектов.
